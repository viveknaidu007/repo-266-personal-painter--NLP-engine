# %% [markdown]
# # backend

# %%
mkdir personal-painter
cd personal-painter
mkdir backend
cd backend
python -m venv venv
source venv/bin/activate  # On Windows: venv\Scripts\activate

# %%
fastapi==0.110.0
uvicorn==0.29.0
pydantic==2.6.4
google-generativeai==0.5.0  # Gemini API
python-dotenv==1.0.1       # For .env file

# %%
pip install -r requirements.txt

# %%
#step by step update:

backend/app/data/images.json:

backend/app/models/schemas.py

backend/app/services/painter.py

backend/app/services/search_engine.py

backend/app/routes/chat.py

backend/app/routes/search.py

backend/app/main.py

# %%
cd backend
uvicorn app.main:app --reload --port 8000

# %% [markdown]
# # frontend

# %%
npx create-vite@latest frontend --template react
cd frontend
npm install
npm install axios

# %%
#:frontend/vite.config.js

import { defineConfig } from 'vite'
import react from '@vitejs/plugin-react'

export default defineConfig({
  plugins: [react()],
  server: {
    proxy: {
      '/api': 'http://localhost:8000'  // Proxy API requests to backend
    }
  }
})

# %%
* step by step updated:

# frontend/src/components/ChatWindow.jsx

# frontend/src/components/SearchBar.jsx

# frontend/src/App.jsx:

# frontend/src/styles.css:

# %%
cd frontend
npm run dev

# %% [markdown]
# # aim:

# %%
    Personal Painter:
        Build a chat system (text/voice) for users to discuss emotions/themes (e.g., regret, hope).
        Convert conversation into a detailed, personalized prompt using an LLM (Gemini).
        Generate and return 3 new image options (simulated).
        
    Natural Language Search Engine:
        Create a search tool for users to query images/collections in natural language.
        Search metadata (descriptions, labels) using keyword convergence, not embeddings.
        Return 20 images or 5 collections, sorted by best-fit score.
